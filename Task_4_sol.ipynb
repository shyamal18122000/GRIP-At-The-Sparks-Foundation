# %% [markdown]
# # By Shyamal Krishna Agrawal
# # The Sparks Foundation
# ## Data Science & Business Analytics Intern
# ### Task 4: Exploratory Data Analysis on dataset Global Terrorism
# ###### Data Source: https://bit.ly/2TK5Xn5
# ###### Problem Statement : As a security/defense analyst, try to find out the hot zone of terrorism.

# %%
# Importing all libraries required in this notebook
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv("/content/globalterrorismdb_0718dist.csv", low_memory=False, encoding='latin-1')
df.head()
# Out:
#         eventid  iyear  imonth  iday  ... INT_IDEO  INT_MISC INT_ANY  related
# 0  197000000001   1970       7     2  ...        0         0       0      NaN
# 1  197000000002   1970       0     0  ...        1         1       1      NaN
# 2  197001000001   1970       1     0  ...       -9         1       1      NaN
# 3  197001000002   1970       1     0  ...       -9         1       1      NaN
# 4  197001000003   1970       1     0  ...       -9         1       1      NaN
#
# [5 rows x 135 columns]

# %%
df.shape
# Out:
# (181691, 135)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
df.describe()
# Out:
#             eventid          iyear  ...       INT_MISC        INT_ANY
# count  1.816910e+05  181691.000000  ...  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997  ...       0.090010      -3.945952
# std    1.325957e+09      13.259430  ...       0.568457       4.691325
# min    1.970000e+11    1970.000000  ...      -9.000000      -9.000000
# 25%    1.991021e+11    1991.000000  ...       0.000000      -9.000000
# 50%    2.009022e+11    2009.000000  ...       0.000000       0.000000
# 75%    2.014081e+11    2014.000000  ...       0.000000       0.000000
# max    2.017123e+11    2017.000000  ...       1.000000       1.000000
#
# [8 rows x 77 columns]

# %%
df.columns.values
# Out:
# array(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'specificity',
#        'vicinity', 'location', 'summary', 'crit1', 'crit2', 'crit3',
#        'doubtterr', 'alternative', 'alternative_txt', 'multiple',
#        'success', 'suicide', 'attacktype1', 'attacktype1_txt',
#        'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt',
#        'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt',
#        'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2',
#        'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2',
#        'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt',
#        'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3',
#        'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2',
# ...

# %%
df.count()
# Out:
# eventid       181691
# iyear         181691
# imonth        181691
# iday          181691
# approxdate      9239
#                ...
# INT_LOG       181691
# INT_IDEO      181691
# INT_MISC      181691
# INT_ANY       181691
# related        25038
# Length: 135, dtype: int64

# %%
df.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
missing_percentage = df.isnull().sum()*100/len(df)
missing_percentage
# Out:
# eventid        0.000000
# iyear          0.000000
# imonth         0.000000
# iday           0.000000
# approxdate    94.914993
#                 ...
# INT_LOG        0.000000
# INT_IDEO       0.000000
# INT_MISC       0.000000
# INT_ANY        0.000000
# related       86.219461
# Length: 135, dtype: float64

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='viridis')

# %%
df.dropna(axis=1,inplace=True)

# %%
df.head(5)
# Out:
#         eventid  iyear  imonth  iday  ...  INT_LOG  INT_IDEO INT_MISC  INT_ANY
# 0  197000000001   1970       7     2  ...        0         0        0        0
# 1  197000000002   1970       0     0  ...        0         1        1        1
# 2  197001000001   1970       1     0  ...       -9        -9        1        1
# 3  197001000002   1970       1     0  ...       -9        -9        1        1
# 4  197001000003   1970       1     0  ...       -9        -9        1        1
#
# [5 rows x 29 columns]

# %%
df.shape
# Out:
# (181691, 29)

# %%
plt.figure(figsize=(30,30))
sns.heatmap(df.corr(), annot=True)

# %%
df.corr()
# Out:
#               eventid     iyear    imonth  ...  INT_IDEO  INT_MISC   INT_ANY
# eventid      1.000000  0.999996  0.002706  ... -0.133252 -0.077852 -0.175605
# iyear        0.999996  1.000000  0.000139  ... -0.133253 -0.077847 -0.175596
# imonth       0.002706  0.000139  1.000000  ... -0.002034 -0.002554 -0.006336
# iday         0.018336  0.018254  0.005497  ... -0.001621 -0.002027 -0.001199
# extended     0.091761  0.091754 -0.000468  ...  0.075147  0.027335  0.080767
# country     -0.135039 -0.135023 -0.006305  ...  0.067564  0.207281  0.153118
# region       0.401371  0.401384 -0.002999  ... -0.071917  0.043139 -0.047900
# vicinity     0.070646  0.070659 -0.004501  ...  0.015119 -0.008232  0.010325
# crit1        0.002019  0.001995  0.001568  ...  0.089888  0.015692  0.082288
# crit2        0.026215  0.026211  0.001734  ... -0.023829 -0.012980 -0.027752
# crit3       -0.016789 -0.016784  0.000176  ... -0.138251 -0.036112 -0.130216
# ...

# %%
s = pd.value_counts(df['targtype1_txt'])
s1 = pd.Series({'nunique': len(s), 'unique values': s.index.tolist()})
s.append(s1)
# Out:
# Private Citizens & Property                                                   43511
# Military                                                                      27984
# Police                                                                        24506
# Government (General)                                                          21283
# Business                                                                      20669
# Transportation                                                                 6799
# Utilities                                                                      6023
# Unknown                                                                        5898
# Religious Figures/Institutions                                                 4440
# Educational Institution                                                        4322
# Government (Diplomatic)                                                        3573
# ...

# %%
s = pd.value_counts(df['region_txt'])
s1 = pd.Series({'nunique': len(s), 'unique values': s.index.tolist()})
s.append(s1)
# Out:
# Middle East & North Africa                                                 50474
# South Asia                                                                 44974
# South America                                                              18978
# Sub-Saharan Africa                                                         17550
# Western Europe                                                             16639
# Southeast Asia                                                             12485
# Central America & Caribbean                                                10344
# Eastern Europe                                                              5144
# North America                                                               3456
# East Asia                                                                    802
# Central Asia                                                                 563
# Australasia & Oceania                                                        282
# ...

# %%
s = pd.value_counts(df['country_txt'])
s1 = pd.Series({'nunique': len(s), 'unique values': s.index.tolist()})
s.append(s1)
# Out:
# Iraq                                                         24636
# Pakistan                                                     14368
# Afghanistan                                                  12731
# India                                                        11960
# Colombia                                                      8306
#                                        ...
# St. Lucia                                                        1
# Andorra                                                          1
# International                                                    1
# nunique                                                        205
# unique values    [Iraq, Pakistan, Afghanistan, India, Colombia,...
# Length: 207, dtype: object

# %%
s = pd.value_counts(df['gname'])
s1 = pd.Series({'nunique': len(s), 'unique values': s.index.tolist()})
s.append(s1)
# Out:
# Unknown                                                                                         82782
# Taliban                                                                                          7478
# Islamic State of Iraq and the Levant (ISIL)                                                      5613
# Shining Path (SL)                                                                                4555
# Farabundo Marti National Liberation Front (FMLN)                                                 3351
#                                                                           ...
# Anti-Communist Vigilante Patrol                                                                     1
# RIF Popular Front                                                                                   1
# Temple Mount Faithful Movement                                                                      1
# ...

# %%
s = pd.value_counts(df['weaptype1_txt'])
s1 = pd.Series({'nunique': len(s), 'unique values': s.index.tolist()})
s.append(s1)
# Out:
# Explosives                                                                                                                 92426
# Firearms                                                                                                                   58524
# Unknown                                                                                                                    15157
# Incendiary                                                                                                                 11135
# Melee                                                                                                                       3655
# Chemical                                                                                                                     321
# Sabotage Equipment                                                                                                           141
# ...

# %%
plt.rcParams['figure.figsize']=15,11
sns.countplot(x=df['weaptype1_txt'])
plt.ylabel('Number of attacks')
plt.xticks(rotation=90)
plt.xlabel('Attack Year')
plt.title('Increase in Terror',size=25, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Increase in Terror')

# %%
plt.rcParams['figure.figsize']=60,44
sns.countplot(x=df['region_txt'], hue='success', data=df)
plt.ylabel('Number of attacks')
plt.xticks(rotation=90)
plt.xlabel('Attack region/country')
plt.title('Region wise Attack and whether successful or not',size=25, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Country wise Attack and whether successful or not')

# %%
plt.rcParams['figure.figsize']=15,11
sns.countplot(x=df['iyear'])
plt.ylabel('Number of attacks')
plt.xticks(rotation=90)
plt.xlabel('Attack Year')
plt.title('Increase in Terror',size=25, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Increase in Terror')

# %%
plt.rcParams['figure.figsize']=15,11
sns.countplot(x=df['iyear'], hue='success', data=df)
plt.ylabel('Number of attacks')
plt.xticks(rotation=90)
plt.xlabel('Attack Year')
plt.title('Increase in Terror',size=18, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Increase in Terror')

# %%
plt.rcParams['figure.figsize']=15,11
sns.barplot(x=df['attacktype1_txt'].value_counts()[:20].index,y=df['attacktype1_txt'].value_counts()[:20].values)
plt.ylabel('Total Attack', fontsize=20)
plt.xticks(rotation=90)
plt.xlabel('Attack Type', fontsize=20)
plt.title('Attack types',size=18, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Attack types')

# %%
plt.rcParams['figure.figsize']=15,11
sns.barplot(x=df['country_txt'].value_counts()[:20].index,y=df['country_txt'].value_counts()[:20].values)
plt.ylabel('Number of attacks')
plt.xticks(rotation=90)
plt.xlabel('Attack Region/country')
plt.title('Country wise Attack',size=18, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Country wise Attack')

# %%
plt.rcParams['figure.figsize']=60,44
sns.countplot(x=df['country_txt'], hue='success', data=df)
plt.ylabel('Number of attacks')
plt.xticks(rotation=90)
plt.xlabel('Attack region/country')
plt.title('Country wise Attack and whether successful or not',size=25, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Country wise Attack and whether successful or not')

# %% [markdown]
# # Conclusion
# #### Iraq ranked first on the global terrorism for their terrorist activity in both successful attack and unsuccessful attack followed by Pakistan, Afganistan, India, Colombia, Philippines and so on
#
# #### Most targeted areas are private citizens, property, military, police, and so on.
#
# #### Explosives, Firearms, Incendiary are there mostly used weapons
#
# #### Global terror attack deaths rose sharply starting year 2012
#
# #### In conclusion with the ranking, Iraq suffered from most terrorist attacks in 2014
